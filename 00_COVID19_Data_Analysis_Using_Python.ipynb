# %% [markdown]
# <a href="https://colab.research.google.com/github/mohd-faizy/08P_COVID19_Data_Analysis_Using_Python/blob/master/00_COVID19_Data_Analysis_Using_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # __COVID19 Data Analysis Using Python__

# %% [markdown]
# ## __Task 1__

# %%
# Importing the modules
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ## __Task 2__

# %% [markdown]
# ### __Task 2.1: importing covid19 datase__

# %%
# Importing the covid-19 DataSet
corona_dataset_csv = pd.read_csv('https://data.humdata.org/hxlproxy/api/data-preview.csv?url=https%3A%2F%2Fraw.githubusercontent.com%2FCSSEGISandData%2FCOVID-19%2Fmaster%2Fcsse_covid_19_data%2Fcsse_covid_19_time_series%2Ftime_series_covid19_confirmed_global.csv&filename=time_series_covid19_confirmed_global.csv')
corona_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region  ...  8/17/20  8/18/20
# 0                           NaN          Afghanistan  ...    37599    37599
# 1                           NaN              Albania  ...     7499     7654
# 2                           NaN              Algeria  ...    39025    39444
# 3                           NaN              Andorra  ...     1005     1005
# 4                           NaN               Angola  ...     1935     1966
# 5                           NaN  Antigua and Barbuda  ...       93       93
# 6                           NaN            Argentina  ...   299126   305966
# 7                           NaN              Armenia  ...    41701    41846
# 8  Australian Capital Territory            Australia  ...      113      113
# 9               New South Wales            Australia  ...     3959     3966
#
# [10 rows x 214 columns]

# %% [markdown]
# __Let's check the shape of the dataframe__

# %%
corona_dataset_csv.shape
# Out:
# (266, 214)

# %% [markdown]
# ### __Task 2.2: Delete the useless columns__

# %%
corona_dataset_csv.drop(['Lat','Long'],axis=1,inplace=True)

# %%
corona_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region  ...  8/17/20  8/18/20
# 0                           NaN          Afghanistan  ...    37599    37599
# 1                           NaN              Albania  ...     7499     7654
# 2                           NaN              Algeria  ...    39025    39444
# 3                           NaN              Andorra  ...     1005     1005
# 4                           NaN               Angola  ...     1935     1966
# 5                           NaN  Antigua and Barbuda  ...       93       93
# 6                           NaN            Argentina  ...   299126   305966
# 7                           NaN              Armenia  ...    41701    41846
# 8  Australian Capital Territory            Australia  ...      113      113
# 9               New South Wales            Australia  ...     3959     3966
#
# [10 rows x 212 columns]

# %% [markdown]
# ### __Task 2.3: Aggregating the rows by the country__

# %%
corona_dataset_aggregated = corona_dataset_csv.groupby("Country/Region").sum()

# %%
corona_dataset_aggregated.head(30)
# Out:
#                         1/22/20  1/23/20  1/24/20  ...  8/16/20  8/17/20  8/18/20
# Country/Region                                     ...
# Afghanistan                   0        0        0  ...    37596    37599    37599
# Albania                       0        0        0  ...     7380     7499     7654
# Algeria                       0        0        0  ...    38583    39025    39444
# Andorra                       0        0        0  ...      989     1005     1005
# Angola                        0        0        0  ...     1906     1935     1966
# Antigua and Barbuda           0        0        0  ...       93       93       93
# Argentina                     0        0        0  ...   294569   299126   305966
# Armenia                       0        0        0  ...    41663    41701    41846
# Australia                     0        0        0  ...    23558    23773    23989
# Austria                       0        0        0  ...    23370    23534    23829
# Azerbaijan                    0        0        0  ...    34219    34343    34474
# Bahamas                       0        0        0  ...     1315     1329     1424
# Bahrain                       0        0        0  ...    46835    47185    47581
# Bangladesh                    0        0        0  ...   276549   279144   282344
# Barbados                      0        0        0  ...      151      152      153
# Belarus                       0        0        0  ...    69516    69589    69673
# Belgium                       0        0        0  ...    78323    78534    78897
# Belize                        0        0        0  ...      452      475      475
# Benin                         0        0        0  ...     2063     2063     2063
# Bhutan                        0        0        0  ...      138      141      147
# Bolivia                       0        0        0  ...   100344   101223   103019
# Bosnia and Herzegovina        0        0        0  ...    15801    16111    16351
# Botswana                      0        0        0  ...     1214     1308     1308
# Brazil                        0        0        0  ...  3340197  3359570  3407354
# Brunei                        0        0        0  ...      142      142      142
# Bulgaria                      0        0        0  ...    14365    14500    14669
# Burkina Faso                  0        0        0  ...     1267     1280     1280
# Burma                         0        0        0  ...      375      376      376
# Burundi                       0        0        0  ...      413      413      416
# Cabo Verde                    0        0        0  ...     3179     3203     3253
#
# [30 rows x 210 columns]

# %%
corona_dataset_aggregated.shape
# Out:
# (188, 210)

# %% [markdown]
# ### __Task 2.4: Visualizing data related to a country for example China__

# %%
corona_dataset_aggregated.loc['US'].plot()
corona_dataset_aggregated.loc['Brazil'].plot()
corona_dataset_aggregated.loc['India'].plot()
corona_dataset_aggregated.loc['Russia'].plot()
corona_dataset_aggregated.loc['Brazil'].plot()
corona_dataset_aggregated.loc['Pakistan'].plot()
plt.legend()

# %% [markdown]
# ## __Task 3__

# %% [markdown]
# __Calculating a good measure__

# %% [markdown]
# we need to find a good measure reperestend as a number, describing the spread of the virus in a country.

# %%
corona_dataset_aggregated.loc['India'].plot()

# %% [markdown]
# ### __Task 3.1: caculating the first derivative of the curve__

# %%
corona_dataset_aggregated.loc['India'].diff().plot()

# %% [markdown]
# ### __Task 3.2: Finding the maxmimum infection rate for China__

# %%
corona_dataset_aggregated.loc['US'].diff().max()
# Out:
# 77255.0

# %%
corona_dataset_aggregated.loc['India'].diff().max()
# Out:
# 66999.0

# %%
corona_dataset_aggregated.loc['Brazil'].diff().max()
# Out:
# 69074.0

# %% [markdown]
# ### __Task 3.3: find maximum infection rate for all of the countries__

# %%
countries = list(corona_dataset_aggregated.index)
max_infection_rates = []
for country in countries :
    max_infection_rates.append(corona_dataset_aggregated.loc[country].diff().max())
corona_dataset_aggregated['max infection rate'] = max_infection_rates

# %%
corona_dataset_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  ...  8/17/20  8/18/20  max infection rate
# Country/Region                             ...
# Afghanistan           0        0        0  ...    37599    37599               915.0
# Albania               0        0        0  ...     7499     7654               155.0
# Algeria               0        0        0  ...    39025    39444               675.0
# Andorra               0        0        0  ...     1005     1005                79.0
# Angola                0        0        0  ...     1935     1966               100.0
#
# [5 rows x 211 columns]

# %% [markdown]
# #### __Task 3.4: create a new dataframe with only needed column__

# %%
corona_data = pd.DataFrame(corona_dataset_aggregated['max infection rate'])

# %%
corona_data.head(-10)
# Out:
#                       max infection rate
# Country/Region
# Afghanistan                        915.0
# Albania                            155.0
# Algeria                            675.0
# Andorra                             79.0
# Angola                             100.0
# ...                                  ...
# Turkey                            5138.0
# US                               77255.0
# Uganda                              84.0
# Ukraine                           1878.0
# United Arab Emirates               994.0
#
# [178 rows x 1 columns]

# %% [markdown]
# ## __Task 4__

# %% [markdown]
# > - _Importing the $WorldHappinessReport$.csv dataset_
# - _selecting needed columns for our analysis._
# - _join the $datasets$._
# - _Calculate the $correlations$ as the result of our analysis._

# %% [markdown]
# ### __Task 4.1 : importing the dataset__

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-93672cd1-77ad-4fdf-9b50-0f860b4619f7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-93672cd1-77ad-4fdf-9b50-0f860b4619f7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving world_happiness_report_2019.csv to world_happiness_report_2019.csv

# %%
ls
# Out:
# sample_data/  world_happiness_report_2019.csv

# %%
world_happiness_report = pd.read_csv("/content/world_happiness_report_2019.csv")
world_happiness_report.head()
# Out:
#    Overall rank Country or region  ...  Generosity  Perceptions of corruption
# 0             1           Finland  ...       0.153                      0.393
# 1             2           Denmark  ...       0.252                      0.410
# 2             3            Norway  ...       0.271                      0.341
# 3             4           Iceland  ...       0.354                      0.118
# 4             5       Netherlands  ...       0.322                      0.298
#
# [5 rows x 9 columns]

# %%
world_happiness_report.shape
# Out:
# (156, 9)

# %% [markdown]
# ### __Task 4.2: let's drop the useless columns__

# %%
columns_to_dropped = ['Overall rank','Score','Generosity','Perceptions of corruption']
world_happiness_report.drop(columns_to_dropped,axis=1 , inplace=True)

# %%
world_happiness_report.head()
# Out:
#   Country or region  ...  Freedom to make life choices
# 0           Finland  ...                         0.596
# 1           Denmark  ...                         0.592
# 2            Norway  ...                         0.603
# 3           Iceland  ...                         0.591
# 4       Netherlands  ...                         0.557
#
# [5 rows x 5 columns]

# %% [markdown]
# ### __Task 4.3: changing the indices of the dataframe__

# %%
world_happiness_report.set_index(['Country or region'],inplace=True)
world_happiness_report.head()
# Out:
#                    GDP per capita  ...  Freedom to make life choices
# Country or region                  ...
# Finland                     1.340  ...                         0.596
# Denmark                     1.383  ...                         0.592
# Norway                      1.488  ...                         0.603
# Iceland                     1.380  ...                         0.591
# Netherlands                 1.396  ...                         0.557
#
# [5 rows x 4 columns]

# %% [markdown]
# ### __Task4.4: now let's join two dataset we have prepared__

# %% [markdown]
# __Corona Dataset :__

# %%
corona_data.head()
# Out:
#                 max infection rate
# Country/Region
# Afghanistan                  915.0
# Albania                      155.0
# Algeria                      675.0
# Andorra                       79.0
# Angola                       100.0

# %% [markdown]
# __wolrd happiness report Dataset:__

# %%
world_happiness_report.head()
# Out:
#                    GDP per capita  ...  Freedom to make life choices
# Country or region                  ...
# Finland                     1.340  ...                         0.596
# Denmark                     1.383  ...                         0.592
# Norway                      1.488  ...                         0.603
# Iceland                     1.380  ...                         0.591
# Netherlands                 1.396  ...                         0.557
#
# [5 rows x 4 columns]

# %%
data = world_happiness_report.join(corona_data).copy()
data.head()
# Out:
#                    GDP per capita  ...  max infection rate
# Country or region                  ...
# Finland                     1.340  ...               267.0
# Denmark                     1.383  ...               391.0
# Norway                      1.488  ...               386.0
# Iceland                     1.380  ...                99.0
# Netherlands                 1.396  ...              1346.0
#
# [5 rows x 5 columns]

# %% [markdown]
# ### __Task 4.5: correlation matrix__

# %% [markdown]
# it is representing the correlation between every two columns of our dataset

# %%
data.corr()
# Out:
#                               GDP per capita  ...  max infection rate
# GDP per capita                      1.000000  ...            0.104329
# Social support                      0.754906  ...            0.071244
# Healthy life expectancy             0.835462  ...            0.094357
# Freedom to make life choices        0.379079  ...            0.085067
# max infection rate                  0.104329  ...            1.000000
#
# [5 rows x 5 columns]

# %% [markdown]
# ## __Task 5__

# %% [markdown]
# ### __Visualization of the results__

# %%
data.head()
# Out:
#                    GDP per capita  ...  max infection rate
# Country or region                  ...
# Finland                     1.340  ...               267.0
# Denmark                     1.383  ...               391.0
# Norway                      1.488  ...               386.0
# Iceland                     1.380  ...                99.0
# Netherlands                 1.396  ...              1346.0
#
# [5 rows x 5 columns]

# %% [markdown]
# ### __Task 5.1: Plotting GDP vs maximum Infection rate__

# %%
x = data['GDP per capita']
y = data['max infection rate']
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %% [markdown]
# ### __Task 5.2: Plotting Social support vs maximum Infection rate__

# %%
x = data['Social support']
y = data['max infection rate']
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %% [markdown]
# ### __Task 5.3: Plotting Healthy life expectancy vs maximum Infection rate__

# %%
x = data['Healthy life expectancy']
y = data['max infection rate']
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %% [markdown]
# ### __Task 5.4: Plotting Freedom to make life choices vs maximum Infection rate__

# %%
x = data['Freedom to make life choices']
y = data['max infection rate']
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))
